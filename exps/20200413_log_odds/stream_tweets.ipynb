# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
import pickle

# %%
class listener(StreamListener):
    def __init__(self):
        self.count = 0
    
    def on_data(self, data):
        text = json.loads(data)['text']
        with open('sample_tweets.txt','a') as tf:
            tf.write(text) 
        self.count += 1
        if self.count % 100 == 0:
            print('collected {} tweets'.format(self.count))
        return(True)

    def on_error(self, status):
        print(status)
    


api_keys = pickle.load(open('../20200329_data_collection/api_keys.p', 'rb'))
api_key = api_keys['consumer_key']
api_secret_key = api_keys['consumer_secret']
access_token = api_keys['access_key']
access_token_secret = api_keys['access_secret']
# Connect to Twitter API using the secrets
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)

twitterStream = Stream(auth, listener(), tweet_mode= 'extended')
twitterStream.sample(languages=['en'])
# Out:
# collected 100 tweets
# collected 200 tweets
# collected 300 tweets
# collected 400 tweets
# collected 500 tweets
# collected 600 tweets
# collected 700 tweets
# collected 800 tweets
# collected 900 tweets
# collected 1000 tweets
# collected 1100 tweets
# collected 1200 tweets
# collected 1300 tweets
# collected 1400 tweets
# collected 1500 tweets
# collected 1600 tweets
# collected 1700 tweets
# collected 1800 tweets
# collected 1900 tweets
# collected 2000 tweets
# collected 2100 tweets
# collected 2200 tweets
# collected 2300 tweets
# collected 2400 tweets
# collected 2500 tweets
# collected 2600 tweets
# collected 2700 tweets
# collected 2800 tweets
# collected 2900 tweets
# collected 3000 tweets
# collected 3100 tweets
# collected 3200 tweets
# collected 3300 tweets
# collected 3400 tweets
# collected 3500 tweets
# collected 3600 tweets
# collected 3700 tweets
# collected 3800 tweets
# collected 3900 tweets
# collected 4000 tweets
# collected 4100 tweets
# collected 4200 tweets
# ...
